# %%
import sys
from __future__ import division

# %%
import numpy as np
from phasor.utilities.ipynb.displays import *
#from YALL.utilities.tabulate import tabulate

import declarative

from declarative.bunch import (
    DeepBunch
)

import phasor.math.dispatched as dmath 
#import phasor.math.dispatch_sympy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import phasor.utilities.version as version
print(version.foundations_version())

from phasor.utilities.np import logspaced

from phasor import optics
from phasor import base 
from phasor import signals 
from phasor import system
from phasor import readouts 
from phasor import mechanical
# Out:
# b'2017-04-02 22:41:49 -0400 (87cf294591536591a3d2b62cc64392752bb95e54)'

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.01, 100, 100),
)
sys.own.F1 = mechanical.ForceSource()
#sys.own.R1 = mechanical.ForceReadout(
#    terminal = sys.F1.A,
#)
sys.own.R1 = mechanical.DisplacementReadout(
    terminal = sys.F1.A,
)
sys.own.M1 = mechanical.Mass(mass_kg = 1)
sys.M1.A.bond(sys.F1.A)
sys.own.RAC1 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R1.d.o,
)

readoutI =  sys.RAC1

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(readoutI.F_Hz.val, abs(readoutI.AC_sensitivity))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(readoutI.AC_sensitivity, deg = True))

#readoutI.AC_sensitivity

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.01, 100, 100),
)
sys.own.F1 = mechanical.ForceSource()
#sys.own.R1 = mechanical.ForceReadout(
#    terminal = sys.F1.A,
#)
sys.own.R1 = mechanical.DisplacementReadout(
    terminal = sys.F1.A,
)
sys.own.M1 = mechanical.Mass(mass_kg = 1)
sys.own.M2 = mechanical.Mass(mass_kg = 1)
sys.M1.A.bond(sys.F1.A)
sys.M1.A.bond(sys.M2.A)
sys.own.RAC1 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R1.d.o,
)

readoutI =  sys.RAC1

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(readoutI.F_Hz.val, abs(readoutI.AC_sensitivity))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(readoutI.AC_sensitivity, deg = True))

#readoutI.AC_sensitivity

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.01, 100, 1000),
)
sys.own.F1 = mechanical.ForceSource()
sys.own.R1 = mechanical.DisplacementReadout(
    terminal = sys.F1.A,
)
sys.own.M1 = mechanical.Mass(mass_kg = 1)
sys.own.S1 = mechanical.TerminatorSpring(elasticity_N_m = 1)
sys.own.D1 = mechanical.TerminatorDamper(resistance_Ns_m = .1)
sys.M1.A.bond(sys.F1.A)
sys.S1.A.bond(sys.F1.A)
sys.D1.A.bond(sys.F1.A)
sys.own.RAC1 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R1.d.o,
)

readoutI =  sys.RAC1

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(readoutI.F_Hz.val, abs(readoutI.AC_sensitivity))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(readoutI.AC_sensitivity, deg = True))

#readoutI.AC_sensitivity

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.01, 100, 1000),
)
sys.own.F1 = mechanical.ForceSource()
sys.own.R1 = mechanical.DisplacementReadout(
    terminal = sys.F1.A,
)
sys.own.M1 = mechanical.Mass(mass_kg = 1)
sys.own.S1 = mechanical.TerminatorSpring(elasticity_N_m = 1)
sys.own.D1 = mechanical.TerminatorDamper(resistance_Ns_m = .1)
sys.M1.A.bond(sys.F1.A)
sys.M1.A.bond(sys.F1.A)
sys.S1.A.bond(sys.F1.A)
sys.D1.A.bond(sys.F1.A)
sys.own.RAC1 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R1.d.o,
)

readoutI =  sys.RAC1

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(readoutI.F_Hz.val, abs(readoutI.AC_sensitivity))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(readoutI.AC_sensitivity, deg = True))

#readoutI.AC_sensitivity

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.01, 100, 1000),
)
sys.own.F1 = mechanical.ForceSource()
sys.own.R1 = mechanical.DisplacementReadout(
    terminal = sys.F1.A,
)
sys.own.M1 = mechanical.XYZMass(
    mass_kg = 1,
    
)
sys.own.S1 = mechanical.XYZTerminatorSpring(
    elasticity_N_m = 1,
)
sys.own.D1 = mechanical.XYZTerminatorDamper(
    resistance_Ns_m = .1,
)
sys.S1.A.bond(sys.M1.A)
sys.S1.A.bond(sys.M1.A)
sys.D1.A.bond(sys.M1.A)
sys.F1.A.bond(sys.M1.A.X)
sys.own.RAC1 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R1.d.o,
)

readoutI =  sys.RAC1

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(readoutI.F_Hz.val, abs(readoutI.AC_sensitivity))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(readoutI.AC_sensitivity, deg = True))

#readoutI.AC_sensitivity

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.01, 100, 1000),
)
sys.own.F1 = mechanical.ForceSource()
sys.own.R1 = mechanical.DisplacementReadout(
    terminal = sys.F1.A,
)
sys.own.T1 = mechanical.XYZTerminatorOpen()
sys.own.M1 = mechanical.XYZMass(
    mass_kg = .000001,
)
sys.own.M1.A.bond(sys.T1.A)
sys.own.F1.A.bond(sys.T1.X.A)
sys.own.L1 = mechanical.XYZMoment(
    moment_kgmsq = 1,
)
sys.own.L1D = mechanical.XYZMomentDriver(
    displacementXYZ = [0,1,0],
)
sys.L1D.A.bond(sys.T1.A)
sys.L1D.L.bond(sys.L1.L)
sys.own.RAC1 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R1.d.o,
)

readoutI =  sys.RAC1

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(readoutI.F_Hz.val, abs(readoutI.AC_sensitivity))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(readoutI.AC_sensitivity, deg = True))

#readoutI.AC_sensitivity
# Out:
# DK{▲:L1D|🔌:Ax⥳} DK{▲:L1D|🔌:Ax⥲} 0.333333333333
# DK{▲:L1D|🔌:Az⥳} DK{▲:L1D|🔌:Az⥲} 0.333333333333
# DK{▲:L1D|🔌:Bx⥳} DK{▲:L1D|🔌:Bx⥲} 0.333333333333
# DK{▲:L1D|🔌:Bz⥳} DK{▲:L1D|🔌:Bz⥲} 0.333333333333
# DK{▲:L1D|🔌:Lx⥳} DK{▲:L1D|🔌:Lx⥲} 0.333333333333
# DK{▲:L1D|🔌:Ly⥳} DK{▲:L1D|🔌:Ly⥲} 1.0
# DK{▲:L1D|🔌:Lz⥳} DK{▲:L1D|🔌:Lz⥲} 0.333333333333
# DK{▲:L1D|🔌:Ax⥳} DK{▲:L1D|🔌:Lz⥲} 0.666666666667
# DK{▲:L1D|🔌:Az⥳} DK{▲:L1D|🔌:Lx⥲} -0.666666666667
# DK{▲:L1D|🔌:Lx⥳} DK{▲:L1D|🔌:Az⥲} -0.666666666667
# DK{▲:L1D|🔌:Lz⥳} DK{▲:L1D|🔌:Ax⥲} 0.666666666667
# DK{▲:L1D|🔌:Bx⥳} DK{▲:L1D|🔌:Lz⥲} -0.666666666667
# DK{▲:L1D|🔌:Bz⥳} DK{▲:L1D|🔌:Lx⥲} 0.666666666667
# DK{▲:L1D|🔌:Lx⥳} DK{▲:L1D|🔌:Bz⥲} 0.666666666667
# DK{▲:L1D|🔌:Lz⥳} DK{▲:L1D|🔌:Bx⥲} -0.666666666667
# DK{▲:L1D|🔌:Ax⥳} DK{▲:L1D|🔌:Bx⥲} 0.666666666667
# DK{▲:L1D|🔌:Ay⥳} DK{▲:L1D|🔌:By⥲} 1.0
# DK{▲:L1D|🔌:Az⥳} DK{▲:L1D|🔌:Bz⥲} 0.666666666667
# DK{▲:L1D|🔌:Bx⥳} DK{▲:L1D|🔌:Ax⥲} 0.666666666667
# DK{▲:L1D|🔌:By⥳} DK{▲:L1D|🔌:Ay⥲} 1.0
# DK{▲:L1D|🔌:Bz⥳} DK{▲:L1D|🔌:Az⥲} 0.666666666667
# ...

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.01, 1000, 1000),
)
sys.own.T1 = mechanical.XYZTerminatorOpen()
sys.own.T2 = mechanical.XYZTerminatorOpen()
sys.own.S1 = mechanical.XYZTerminatorSpring(
    elasticity_N_m = 1,
)
sys.own.S2 = mechanical.XYZTerminatorSpring(
    elasticity_N_m = 1,
)
sys.own.M1 = mechanical.XYZMass(
    mass_kg = .0001,
)
sys.own.S1.A.bond(sys.T1.A)
sys.own.M1.A.bond(sys.T1.A)

sys.own.M2 = mechanical.XYZMass(
    mass_kg = .0001,
)
sys.own.S2.A.bond(sys.T2.A)
sys.own.M2.A.bond(sys.T2.A)

sys.own.L1 = mechanical.XYZMoment(
    moment_kgmsq = 1,
)
sys.own.M_com = mechanical.XYZMass(
    mass_kg = .000001,
)

sys.own.L1D = mechanical.XYZMomentDriver(
    displacementXYZ = [0,1,0],
)
sys.L1D.A.bond(sys.T1.A)
sys.L1D.L.bond(sys.L1.L)
sys.own.L2D = mechanical.XYZMomentDriver(
    displacementXYZ = [0,-1,0],
)
sys.L2D.A.bond(sys.T2.A)
sys.L2D.L.bond(sys.L1.L)
sys.L1D.B.bond(sys.L2D.B)
sys.L1D.B.bond(sys.M_com.A)

sys.own.F1 = mechanical.ForceSource()
sys.own.F1.A.bond(sys.T1.X.A)
sys.own.R1 = mechanical.DisplacementReadout(
    terminal = sys.T1.X.A,
)
sys.own.RAC1 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R1.d.o,
)

sys.own.R2 = mechanical.DisplacementReadout(
    terminal = sys.T2.X.A,
)
sys.own.RAC2 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R2.d.o,
)

readout1 =  sys.RAC1
readout2 =  sys.RAC2

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(readout1.F_Hz.val, abs(readout1.AC_sensitivity))
Fb.ax1.semilogx(readout1.F_Hz.val, np.angle(readout1.AC_sensitivity, deg = True))
Fb.ax0.loglog(readout2.F_Hz.val, abs(readout2.AC_sensitivity), ls='--')
Fb.ax1.semilogx(readout2.F_Hz.val, np.angle(readout2.AC_sensitivity, deg = True))
Fb.ax1.set_ylim(-10, 190)
#readoutI.AC_sensitivity
# Out:
# DK{▲:L1D|🔌:Ax⥳} DK{▲:L1D|🔌:Ax⥲} 0.333333333333
# DK{▲:L1D|🔌:Az⥳} DK{▲:L1D|🔌:Az⥲} 0.333333333333
# DK{▲:L1D|🔌:Bx⥳} DK{▲:L1D|🔌:Bx⥲} 0.333333333333
# DK{▲:L1D|🔌:Bz⥳} DK{▲:L1D|🔌:Bz⥲} 0.333333333333
# DK{▲:L1D|🔌:Lx⥳} DK{▲:L1D|🔌:Lx⥲} 0.333333333333
# DK{▲:L1D|🔌:Ly⥳} DK{▲:L1D|🔌:Ly⥲} 1.0
# DK{▲:L1D|🔌:Lz⥳} DK{▲:L1D|🔌:Lz⥲} 0.333333333333
# DK{▲:L1D|🔌:Ax⥳} DK{▲:L1D|🔌:Lz⥲} 0.666666666667
# DK{▲:L1D|🔌:Az⥳} DK{▲:L1D|🔌:Lx⥲} -0.666666666667
# DK{▲:L1D|🔌:Lx⥳} DK{▲:L1D|🔌:Az⥲} -0.666666666667
# DK{▲:L1D|🔌:Lz⥳} DK{▲:L1D|🔌:Ax⥲} 0.666666666667
# DK{▲:L1D|🔌:Bx⥳} DK{▲:L1D|🔌:Lz⥲} -0.666666666667
# DK{▲:L1D|🔌:Bz⥳} DK{▲:L1D|🔌:Lx⥲} 0.666666666667
# DK{▲:L1D|🔌:Lx⥳} DK{▲:L1D|🔌:Bz⥲} 0.666666666667
# DK{▲:L1D|🔌:Lz⥳} DK{▲:L1D|🔌:Bx⥲} -0.666666666667
# DK{▲:L1D|🔌:Ax⥳} DK{▲:L1D|🔌:Bx⥲} 0.666666666667
# DK{▲:L1D|🔌:Ay⥳} DK{▲:L1D|🔌:By⥲} 1.0
# DK{▲:L1D|🔌:Az⥳} DK{▲:L1D|🔌:Bz⥲} 0.666666666667
# DK{▲:L1D|🔌:Bx⥳} DK{▲:L1D|🔌:Ax⥲} 0.666666666667
# DK{▲:L1D|🔌:By⥳} DK{▲:L1D|🔌:Ay⥲} 1.0
# DK{▲:L1D|🔌:Bz⥳} DK{▲:L1D|🔌:Az⥲} 0.666666666667
# ...

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.01, 1000, 1000),
)
sys.own.F1 = mechanical.ForceSource()
sys.own.T1 = mechanical.TerminatorOpen()
sys.own.T2 = mechanical.TerminatorOpen()
sys.own.S1 = mechanical.TerminatorSpring(
    elasticity_N_m = 1,
)
sys.own.M1 = mechanical.Mass(
    mass_kg = .0001,
)
sys.own.S1.A.bond(sys.T1.A)
sys.own.M1.A.bond(sys.T1.A)

sys.own.M2 = mechanical.Mass(
    mass_kg = .0001,
)
sys.own.M2.A.bond(sys.T2.A)
sys.own.F1.A.bond(sys.T1.A)
sys.own.L1 = mechanical.XYZMoment(
    moment_kgmsq = 1,
)
sys.own.L1D = mechanical.MomentDriver(
    displacementXYZ = [0,1,0],
    driveXYZ = [1,0,0],
)
sys.L1D.A.bond(sys.T1.A)
sys.L1D.L.bond(sys.L1.L)
sys.own.L2D = mechanical.MomentDriver(
    displacementXYZ = [0,10,0],
    driveXYZ = [100,0,0],
)
sys.L2D.A.bond(sys.T2.A)
sys.L2D.L.bond(sys.L1.L)

sys.own.R1 = mechanical.DisplacementReadout(
    terminal = sys.T1.A,
)
sys.own.RAC1 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R1.d.o,
)

sys.own.R2 = mechanical.DisplacementReadout(
    terminal = sys.T2.A,
)
sys.own.RAC2 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R2.d.o,
)

readout1 =  sys.RAC1
readout2 =  sys.RAC2

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(readout1.F_Hz.val, abs(readout1.AC_sensitivity))
Fb.ax1.semilogx(readout1.F_Hz.val, np.angle(readout1.AC_sensitivity, deg = True))
Fb.ax0.loglog(readout2.F_Hz.val, abs(readout2.AC_sensitivity))
Fb.ax1.semilogx(readout2.F_Hz.val, np.angle(readout2.AC_sensitivity, deg = True))

#readoutI.AC_sensitivity

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.01, 1000, 1000),
)
sys.own.F1 = mechanical.ForceSource()
sys.own.T1 = mechanical.TerminatorOpen()
sys.own.T2 = mechanical.TerminatorOpen()
sys.own.S1 = mechanical.TerminatorSpring(
    elasticity_N_m = 1,
)
sys.own.M1 = mechanical.Mass(
    mass_kg = .0001,
)
sys.own.S1.A.bond(sys.T1.A)
sys.own.M1.A.bond(sys.T1.A)

sys.own.M2 = mechanical.Mass(
    mass_kg = .0001,
)
sys.own.M2.A.bond(sys.T2.A)
sys.own.F1.A.bond(sys.T1.A)
sys.own.L1 = mechanical.XYZMoment(
    moment_kgmsq = 1,
)
sys.own.L1D = mechanical.MomentDriver(
    displacementXYZ = [0,1,1],
    driveXYZ = [1,0,0],
)
sys.L1D.A.bond(sys.T1.A)
sys.L1D.L.bond(sys.L1.L)
sys.own.L2D = mechanical.MomentDriver(
    displacementXYZ = [0,10,10],
    driveXYZ = [100,0,0],
)
sys.L2D.A.bond(sys.T2.A)
sys.L2D.L.bond(sys.L1.L)

sys.own.R1 = mechanical.DisplacementReadout(
    terminal = sys.T1.A,
)
sys.own.RAC1 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R1.d.o,
)

sys.own.R2 = mechanical.DisplacementReadout(
    terminal = sys.T2.A,
)
sys.own.RAC2 = readouts.ACReadout(
    portD = sys.F1.F.i,
    portN = sys.R2.d.o,
)

readout1 =  sys.RAC1
readout2 =  sys.RAC2

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(readout1.F_Hz.val, abs(readout1.AC_sensitivity))
Fb.ax1.semilogx(readout1.F_Hz.val, np.angle(readout1.AC_sensitivity, deg = True))
Fb.ax0.loglog(readout2.F_Hz.val, abs(readout2.AC_sensitivity))
Fb.ax1.semilogx(readout2.F_Hz.val, np.angle(readout2.AC_sensitivity, deg = True))

#readoutI.AC_sensitivity

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.1, 10, 1000),
)
COM_kg = .0885
sys.own.M_com = mechanical.XYZMass(
    mass_kg = COM_kg,
)
sys.own.L1 = mechanical.XYZMoment(
    moment_kgmsq = 1 * np.array([30677 / 1e9, 37696 / 1e9, 64087 / 1e9]),
)
L_pend_m = .14
#halve the effective mass since there are two pendula for the single mass
k_pend = (COM_kg) * 9.81 / (L_pend_m)

#bounce mode is k_y, set here to be the pendulum k, which is wrong
sys.own.S_left = mechanical.XYZTerminatorSpring(
    elasticity_N_m = [k_pend, k_pend, k_pend],
)
sys.own.D_left = mechanical.XYZTerminatorDamper(
    resistance_Ns_m = .1,
)
sys.own.D_left.A.bond(sys.S_left.A)
sys.own.S_right = mechanical.XYZTerminatorSpring(
    elasticity_N_m = [k_pend, k_pend, k_pend],
)
sys.own.D_right = mechanical.XYZTerminatorDamper(
    resistance_Ns_m = .1,
)
sys.own.D_right.A.bond(sys.S_right.A)
sys.own.Ld_left = mechanical.XYZMomentDriver(
    displacementXYZ = [-.0381,1*.0024,0],
)
sys.Ld_left.A.bond(sys.S_left.A)
sys.Ld_left.B.bond(sys.M_com.A)
sys.Ld_left.L.bond(sys.L1.L)

sys.own.Ld_right = mechanical.XYZMomentDriver(
    displacementXYZ = [+.0381,1*.0024,0],
)
sys.Ld_right.A.bond(sys.S_right.A)
sys.Ld_right.L.bond(sys.L1.L)
sys.Ld_right.B.bond(sys.M_com.A)

sys.own.FL = mechanical.ForceSource()
sys.own.FL.A.bond(sys.M_com.Z.A)

#sys.own.FLd = mechanical.ForceSource()
#sys.own.FLd.A.bond(sys.M_com.Z.A)

sys.own.FP = mechanical.ForceSource()
sys.own.FP.A.bond(sys.L1.X.A)

sys.own.FY = mechanical.ForceSource()
sys.own.FY.A.bond(sys.L1.Y.A)

sys.own.RL = mechanical.DisplacementReadout(
    terminal = sys.M_com.Z.A,
)
sys.own.RP = mechanical.DisplacementReadout(
    terminal = sys.L1.X.A,
)
sys.own.RY = mechanical.DisplacementReadout(
    terminal = sys.L1.Y.A,
)

sys.own.RAC_LL = readouts.ACReadout(
    portD = sys.FL.F.i,
    portN = sys.RL.d.o,
)

sys.own.RAC_PP = readouts.ACReadout(
    portD = sys.FP.F.i,
    portN = sys.RP.d.o,
)

sys.own.RAC_YY = readouts.ACReadout(
    portD = sys.FY.F.i,
    portN = sys.RY.d.o,
)


Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.RAC_LL.F_Hz.val, np.ones_like(sys.RAC_LL.F_Hz.val) * abs(sys.RAC_LL.AC_sensitivity))
Fb.ax1.semilogx(sys.RAC_LL.F_Hz.val, np.ones_like(sys.RAC_LL.F_Hz.val) *np.angle(sys.RAC_LL.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.RAC_PP.F_Hz.val, abs(sys.RAC_PP.AC_sensitivity))
Fb.ax1.semilogx(sys.RAC_PP.F_Hz.val, np.angle(sys.RAC_PP.AC_sensitivity, deg = True))
#Fb.ax0.loglog(sys.RAC_YY.F_Hz.val, abs(sys.RAC_YY.AC_sensitivity))
#Fb.ax1.semilogx(sys.RAC_YY.F_Hz.val, np.angle(sys.RAC_YY.AC_sensitivity, deg = True))
#sys.RAC_PP.AC_sensitivity
Fb.ax0.axvline(1.28)
Fb.ax0.axvline(1.35)
#readoutI.AC_sensitivity
# Out:
# DK{▲:Ld_left|🔌:Ax⥳} DK{▲:Ld_left|🔌:Ax⥲} 2.87790291531e-06
# DK{▲:Ld_left|🔌:Ax⥳} DK{▲:Ld_left|🔌:Ay⥲} 4.56867087806e-05
# DK{▲:Ld_left|🔌:Ay⥳} DK{▲:Ld_left|🔌:Ax⥲} 4.56867087806e-05
# DK{▲:Ld_left|🔌:Ay⥳} DK{▲:Ld_left|🔌:Ay⥲} 0.000725276501892
# DK{▲:Ld_left|🔌:Az⥳} DK{▲:Ld_left|🔌:Az⥲} 0.000728154404808
# DK{▲:Ld_left|🔌:Bx⥳} DK{▲:Ld_left|🔌:Bx⥲} 2.87790291531e-06
# DK{▲:Ld_left|🔌:Bx⥳} DK{▲:Ld_left|🔌:By⥲} 4.56867087806e-05
# DK{▲:Ld_left|🔌:By⥳} DK{▲:Ld_left|🔌:Bx⥲} 4.56867087806e-05
# DK{▲:Ld_left|🔌:By⥳} DK{▲:Ld_left|🔌:By⥲} 0.000725276501892
# DK{▲:Ld_left|🔌:Bz⥳} DK{▲:Ld_left|🔌:Bz⥲} 0.000728154404808
# DK{▲:Ld_left|🔌:Lx⥳} DK{▲:Ld_left|🔌:Lx⥲} 0.999994244194
# DK{▲:Ld_left|🔌:Lx⥳} DK{▲:Ld_left|🔌:Ly⥲} -9.13734175612e-05
# DK{▲:Ld_left|🔌:Ly⥳} DK{▲:Ld_left|🔌:Lx⥲} -9.13734175612e-05
# DK{▲:Ld_left|🔌:Ly⥳} DK{▲:Ld_left|🔌:Ly⥲} 0.998549446996
# DK{▲:Ld_left|🔌:Lz⥳} DK{▲:Ld_left|🔌:Lz⥲} 0.99854369119
# DK{▲:Ld_left|🔌:Ax⥳} DK{▲:Ld_left|🔌:Lz⥲} 0.00239825242943
# ...

# %%
#tip-tilt displacement test
sys = system.system.BGSystem(
    F_AC = logspaced(0.1, 10, 1000),
)
COM_kg = .0885
sys.own.M_com = mechanical.XYZMass(
    mass_kg = COM_kg,
)
sys.own.L1 = mechanical.XYZMoment(
    moment_kgmsq = 1 * np.array([30677 / 1e9, 37696 / 1e9, 64087 / 1e9]),
)
L_pend_m = .14
#halve the effective mass since there are two pendula for the single mass
k_pend = (COM_kg/2) * 9.81 / (L_pend_m)

#bounce mode is k_y, set here to be the pendulum k, which is wrong
sys.own.S_left = mechanical.XYZTerminatorSpring(
    elasticity_N_m = [k_pend, k_pend, k_pend],
)
sys.own.S_right = mechanical.XYZTerminatorSpring(
    elasticity_N_m = [k_pend, k_pend, k_pend],
)
sep = 2 * .0024
sys.own.Ld_left = mechanical.XYZMomentDriver(
    displacementXYZ = [-.0381,sep,0],
    #displacementXYZ = [-1,0,0],
)
sys.own.Ld_left2 = mechanical.XYZMomentDriver(
    displacementXYZ = [-.0381,0,0],
    #displacementXYZ = [-1,0,0],
)
sys.Ld_left.A.bond(sys.S_left.A)
sys.Ld_left2.A.bond(sys.S_left.A)
sys.Ld_left.L.bond(sys.L1.L)
sys.own.M_com.A.bond(sys.Ld_left.B)

sys.own.Ld_right = mechanical.XYZMomentDriver(
    displacementXYZ = [+.0381,sep,0],
    #displacementXYZ = [1,0,0],
)
sys.own.Ld_right2 = mechanical.XYZMomentDriver(
    displacementXYZ = [+.0381,0,0],
    #displacementXYZ = [1,0,0],
)
sys.Ld_right.A.bond(sys.S_right.A)
sys.Ld_right2.A.bond(sys.S_right.A)
sys.Ld_right.L.bond(sys.L1.L)
sys.own.M_com.A.bond(sys.Ld_right.B)

sys.Ld_left2.B.bond(sys.Ld_right2.B)
sys.Ld_left2.L.bond(sys.Ld_right2.L)

sys.own.S_p = mechanical.SeriesSpring(
    elasticity_N_m = 9.81 * COM_kg / sep,
)
sys.own.S_p.A.bond(sys.M_com.Z.A)
sys.own.S_p.B.bond(sys.Ld_left2.B.Z)

sys.own.FLd = mechanical.ForceSource()
sys.own.FLd.A.bond(sys.M_com.Z.A)

sys.own.FLdP = mechanical.ForceSource()
sys.own.FLdP.A.bond(sys.L1.X.A)

sys.own.RP = mechanical.DisplacementReadout(
    terminal = sys.L1.X.A,
)
sys.own.RL = mechanical.DisplacementReadout(
    terminal = sys.M_com.A.Z,
)

sys.own.RAC_LL = readouts.ACReadout(
    portD = sys.FLd.F.i,
    portN = sys.RL.d.o,
)

sys.own.RAC_LP = readouts.ACReadout(
    portD = sys.FLd.F.i,
    portN = sys.RP.d.o,
)

sys.own.RAC_PL = readouts.ACReadout(
    portD = sys.FLdP.F.i,
    portN = sys.RL.d.o,
)

sys.own.RAC_PP = readouts.ACReadout(
    portD = sys.FLdP.F.i,
    portN = sys.RP.d.o,
)

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.RAC_LL.F_Hz.val, np.ones_like(sys.RAC_LL.F_Hz.val) * abs(sys.RAC_LL.AC_sensitivity))
Fb.ax1.semilogx(sys.RAC_LL.F_Hz.val, np.ones_like(sys.RAC_LL.F_Hz.val) *np.angle(sys.RAC_LL.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.RAC_LP.F_Hz.val, np.ones_like(sys.RAC_LP.F_Hz.val) * abs(sys.RAC_LP.AC_sensitivity))
Fb.ax1.semilogx(sys.RAC_LP.F_Hz.val, np.ones_like(sys.RAC_LP.F_Hz.val) *np.angle(sys.RAC_LP.AC_sensitivity, deg = True))

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.RAC_PL.F_Hz.val, np.ones_like(sys.RAC_PL.F_Hz.val) * abs(sys.RAC_PL.AC_sensitivity))
Fb.ax1.semilogx(sys.RAC_PL.F_Hz.val, np.ones_like(sys.RAC_PL.F_Hz.val) *np.angle(sys.RAC_PL.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.RAC_PP.F_Hz.val, np.ones_like(sys.RAC_PP.F_Hz.val) * abs(sys.RAC_PP.AC_sensitivity))
Fb.ax1.semilogx(sys.RAC_PP.F_Hz.val, np.ones_like(sys.RAC_PP.F_Hz.val) *np.angle(sys.RAC_PP.AC_sensitivity, deg = True))
#Fb.ax0.axvline(1.28)
#Fb.ax0.axvline(1.35)
#Fb.ax0.set_ylim(.1,10)
# Out:
# NEW! 2
# NEW! 2
# NEW! 2
# NEW! 2

# %%
#tip-tilt displacement test
sys = system.system.BGSystem(
    F_AC = logspaced(0.1, 10, 1000),
)
from phasor.mechanical.models.HTTS import HTTS
sys.own.htts = HTTS()

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.htts.RAC.L_L.F_Hz.val, np.ones_like(sys.htts.RAC.L_L.F_Hz.val) * abs(sys.htts.RAC.L_L.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.L_L.F_Hz.val, np.ones_like(sys.htts.RAC.L_L.F_Hz.val) *np.angle(sys.htts.RAC.L_L.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.htts.RAC.L_P.F_Hz.val, np.ones_like(sys.htts.RAC.L_P.F_Hz.val) * abs(sys.htts.RAC.L_P.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.L_P.F_Hz.val, np.ones_like(sys.htts.RAC.L_P.F_Hz.val) *np.angle(sys.htts.RAC.L_P.AC_sensitivity, deg = True))

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.htts.RAC.P_L.F_Hz.val, np.ones_like(sys.htts.RAC.P_L.F_Hz.val) * abs(sys.htts.RAC.P_L.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.P_L.F_Hz.val, np.ones_like(sys.htts.RAC.P_L.F_Hz.val) *np.angle(sys.htts.RAC.P_L.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.htts.RAC.P_P.F_Hz.val, np.ones_like(sys.htts.RAC.P_P.F_Hz.val) * abs(sys.htts.RAC.P_P.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.P_P.F_Hz.val, np.ones_like(sys.htts.RAC.P_P.F_Hz.val) *np.angle(sys.htts.RAC.P_P.AC_sensitivity, deg = True))

Fb = mplfigB(Nrows=2)
#Fb.ax0.loglog(sys.htts.RAC.Y_L.F_Hz.val, np.ones_like(sys.htts.RAC.Y_L.F_Hz.val) * abs(sys.htts.RAC.Y_L.AC_sensitivity))
#Fb.ax1.semilogx(sys.htts.RAC.Y_L.F_Hz.val, np.ones_like(sys.htts.RAC.Y_L.F_Hz.val) *np.angle(sys.htts.RAC.P_L.AC_sensitivity, deg = True))
#Fb.ax0.loglog(sys.htts.RAC.Y_P.F_Hz.val, np.ones_like(sys.htts.RAC.Y_P.F_Hz.val) * abs(sys.htts.RAC.Y_P.AC_sensitivity))
#Fb.ax1.semilogx(sys.htts.RAC.Y_P.F_Hz.val, np.ones_like(sys.htts.RAC.Y_P.F_Hz.val) *np.angle(sys.htts.RAC.Y_P.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.htts.RAC.Y_Y.F_Hz.val, np.ones_like(sys.htts.RAC.Y_Y.F_Hz.val) * abs(sys.htts.RAC.Y_Y.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.Y_Y.F_Hz.val, np.ones_like(sys.htts.RAC.Y_Y.F_Hz.val) *np.angle(sys.htts.RAC.Y_Y.AC_sensitivity, deg = True))
#Fb.ax0.axvline(1.28)
#Fb.ax0.axvline(1.35)
#Fb.ax0.set_ylim(.1,10)
# Out:
# [autoreload of phasor.mechanical.models.HTTS failed: Traceback (most recent call last):
#   File "/home/mcculler/local/home_sync/projects/ligoutils/phasor.utilities.ipynb/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/mcculler/local/home_sync/projects/ligoutils/phasor.utilities.ipynb/autoreload.py", line 403, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/mcculler/local/home_sync/projects/ligoutils/phasor.utilities.ipynb/autoreload.py", line 339, in update_generic
#     update(a, b)
#   File "/home/mcculler/local/home_sync/projects/ligoutils/phasor.utilities.ipynb/autoreload.py", line 281, in update_class
#     old_obj = getattr(old, key)
# AttributeError: type object 'HTTS' has no attribute 'd_yaw'
# ]
# NEW! 2
# NEW! 2
# NEW! 2
# NEW! 2

# %%
#tip-tilt displacement test
sys = system.system.BGSystem(
    F_AC = logspaced(0.1, 10, 1000),
)
COM_kg = .0885
sys.own.M_com = mechanical.XYZMass(
    mass_kg = COM_kg,
)
sys.own.L1 = mechanical.XYZMoment(
    moment_kgmsq = 1 * np.array([30677 / 1e9, 37696 / 1e9, 64087 / 1e9]),
)
L_pend_m = .14
#halve the effective mass since there are two pendula for the single mass
k_pend = (COM_kg) * 9.81 / (L_pend_m)

#bounce mode is k_y, set here to be the pendulum k, which is wrong
sys.own.S_left = mechanical.XYZTerminatorSpring(
    elasticity_N_m = [k_pend, k_pend, k_pend],
)
sys.own.S_right = mechanical.XYZTerminatorSpring(
    elasticity_N_m = [k_pend, k_pend, k_pend],
)
sys.own.Ld_left = mechanical.XYZMomentDriver(
    displacementXYZ = [-.0381,0*.0024,0],
)
sys.Ld_left.A.bond(sys.S_left.A)
sys.Ld_left.L.bond(sys.L1.L)
sys.own.M_com.A.bond(sys.Ld_left.B)

sys.own.Ld_right = mechanical.XYZMomentDriver(
    displacementXYZ = [+.0381,0*.0024,0],
)
sys.Ld_right.A.bond(sys.S_right.A)
sys.Ld_right.L.bond(sys.L1.L)
sys.own.M_com.A.bond(sys.Ld_right.B)

#sys.own.FLd = mechanical.ForceSource()
#sys.own.FLd.A.bond(sys.M_com.Z.A)

sys.own.FL = mechanical.DisplacementSource()
sys.own.FL.A.bond(sys.S_left.Z.A)

sys.own.FR = mechanical.DisplacementSource()
sys.own.FR.A.bond(sys.S_right.Z.A)

sys.own.RL = mechanical.DisplacementReadout(
    terminal = sys.S_left.Z.A,
)
sys.own.RC = mechanical.DisplacementReadout(
    terminal = sys.M_com.A.Z,
)

sys.own.RAC_DC = readouts.ACReadout(
    portD = sys.FL.d.i,
    portN = sys.RC.d.o,
)

sys.own.RAC_DC2 = readouts.ACReadout(
    portD = sys.FL.d.i,
    portN = sys.S_left.A.Z.o,
)


print(sys.RAC_DC2.AC_sensitivity)
Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.RAC_DC.F_Hz.val, np.ones_like(sys.RAC_DC.F_Hz.val) * abs(sys.RAC_DC.AC_sensitivity))
Fb.ax1.semilogx(sys.RAC_DC.F_Hz.val, np.ones_like(sys.RAC_DC.F_Hz.val) *np.angle(sys.RAC_DC.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.RAC_DC2.F_Hz.val, np.ones_like(sys.RAC_DC2.F_Hz.val) * abs(sys.RAC_DC2.AC_sensitivity))
Fb.ax1.semilogx(sys.RAC_DC2.F_Hz.val, np.ones_like(sys.RAC_DC2.F_Hz.val) *np.angle(sys.RAC_DC2.AC_sensitivity, deg = True))
#Fb.ax0.axvline(1.28)
#Fb.ax0.axvline(1.35)
#Fb.ax0.set_ylim(.1,10)
# Out:
# /home/mcculler/local/home_sync/projects/declarative/declarative/metaclass.py:69: UserWarning: Need to add class decorator "class_expand"
#   warnings.warn("Need to add class decorator \"class_expand\"")
# NEW! 2
# NEW! 2
# [-2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
#  -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
#  -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
#  -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
#  -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
#  -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
#  -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
#  -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
#  -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
#  -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
#  -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j -2.60066071+0.j
# ...

# %%
sys = system.system.BGSystem(
    F_AC = logspaced(0.1, 10, 1000),
)
COM_kg = .0885
sys.own.M_com = mechanical.Mass(
    mass_kg = COM_kg,
)
sys.own.L1 = mechanical.Mass(
    mass_kg = 30677 / 1e9,
)
L_pend_m = .14
#halve the effective mass since there are two pendula for the single mass
k_pend = (COM_kg) * 9.81 / (L_pend_m)

#bounce mode is k_y, set here to be the pendulum k, which is wrong
sys.own.S_left = mechanical.TerminatorSpring(
    elasticity_N_m = k_pend,
)
sys.own.S_right = mechanical.TerminatorSpring(
    elasticity_N_m = k_pend,
)
sys.own.Ld_left = mechanical.Moment1D(
    displacement = -.0381,
)
sys.Ld_left.A.bond(sys.S_left.A)
sys.Ld_left.L.bond(sys.L1.A)
sys.own.M_com.A.bond(sys.Ld_left.B)

sys.own.Ld_right = mechanical.Moment1D(
    displacement = +.0381,
)
sys.Ld_right.A.bond(sys.S_right.A)
sys.Ld_right.L.bond(sys.L1.A)
sys.own.M_com.A.bond(sys.Ld_right.B)

#sys.own.FLd = mechanical.ForceSource()
#sys.own.FLd.A.bond(sys.M_com.A)

sys.own.FL = mechanical.DisplacementSource()
sys.own.FL.A.bond(sys.S_left.A)

sys.own.FR = mechanical.DisplacementSource()
sys.own.FR.A.bond(sys.S_right.A)

sys.own.RL = mechanical.DisplacementReadout(
    terminal = sys.S_left.A,
)
sys.own.RC = mechanical.DisplacementReadout(
    terminal = sys.M_com.A,
)

sys.own.RAC_DC = readouts.ACReadout(
    portD = sys.FL.d.i,
    portN = sys.RC.d.o,
)

sys.own.RAC_DC2 = readouts.ACReadout(
    portD = sys.FL.d.i,
    portN = sys.RL.d.o,
)


print(sys.RAC_DC2.AC_sensitivity)
Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.RAC_DC.F_Hz.val, np.ones_like(sys.RAC_DC.F_Hz.val) * abs(sys.RAC_DC.AC_sensitivity))
Fb.ax1.semilogx(sys.RAC_DC.F_Hz.val, np.ones_like(sys.RAC_DC.F_Hz.val) *np.angle(sys.RAC_DC.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.RAC_DC2.F_Hz.val, np.ones_like(sys.RAC_DC2.F_Hz.val) * abs(sys.RAC_DC2.AC_sensitivity))
Fb.ax1.semilogx(sys.RAC_DC2.F_Hz.val, np.ones_like(sys.RAC_DC2.F_Hz.val) *np.angle(sys.RAC_DC2.AC_sensitivity, deg = True))
#Fb.ax0.axvline(1.28)
#Fb.ax0.axvline(1.35)
#Fb.ax0.set_ylim(.1,10)
# Out:
# [ 1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
#   1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j  1.+0.j
# ...

# %%
mechanical.XYZMass
# Out:
# phasor.mechanical.xyz.XYZMass

# %%
100 / 6.28
# Out:
# 15.92356687898089

# %%
(31.376 + 44.82)/2
# Out:
# 38.098
