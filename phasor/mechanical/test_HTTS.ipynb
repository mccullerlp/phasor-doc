# %%
import sys
from __future__ import division

# %%
import numpy as np
from phasor.utilities.ipynb.displays import *
#from YALL.utilities.tabulate import tabulate

import declarative

from declarative.bunch import (
    DeepBunch
)

import phasor.math.dispatched as dmath 
#import phasor.math.dispatch_sympy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import phasor.utilities.version as version
print(version.foundations_version())

from phasor.utilities.np import logspaced

from phasor import optics
from phasor import base 
from phasor import signals 
from phasor import system
from phasor import readouts 
from phasor import mechanical
# Out:
# b'2017-04-04 21:41:12 -0400 (f11c5c648f0122c0f60572fba2e4407040b928d7)'

# %%
#tip-tilt displacement test
sys = system.system.BGSystem(
    F_AC = logspaced(.5, 3, 1000),
)
from phasor.mechanical.models.HTTS import HTTS
sys.own.htts = HTTS()

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.htts.RAC.L_L.F_Hz.val, np.ones_like(sys.htts.RAC.L_L.F_Hz.val) * abs(sys.htts.RAC.L_L.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.L_L.F_Hz.val, np.ones_like(sys.htts.RAC.L_L.F_Hz.val) *np.angle(sys.htts.RAC.L_L.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.htts.RAC.L_P.F_Hz.val, np.ones_like(sys.htts.RAC.L_P.F_Hz.val) * abs(sys.htts.RAC.L_P.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.L_P.F_Hz.val, np.ones_like(sys.htts.RAC.L_P.F_Hz.val) *np.angle(sys.htts.RAC.L_P.AC_sensitivity, deg = True))
Fb.ax0.set_xscale('log_zoom')
Fb.ax1.set_xscale('log_zoom')

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.htts.RAC.P_L.F_Hz.val, np.ones_like(sys.htts.RAC.P_L.F_Hz.val) * abs(sys.htts.RAC.P_L.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.P_L.F_Hz.val, np.ones_like(sys.htts.RAC.P_L.F_Hz.val) *np.angle(sys.htts.RAC.P_L.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.htts.RAC.P_P.F_Hz.val, np.ones_like(sys.htts.RAC.P_P.F_Hz.val) * abs(sys.htts.RAC.P_P.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.P_P.F_Hz.val, np.ones_like(sys.htts.RAC.P_P.F_Hz.val) *np.angle(sys.htts.RAC.P_P.AC_sensitivity, deg = True))
Fb.ax0.set_xscale('log_zoom')
Fb.ax1.set_xscale('log_zoom')

Fb = mplfigB(Nrows=2)
#Fb.ax0.loglog(sys.htts.RAC.Y_L.F_Hz.val, np.ones_like(sys.htts.RAC.Y_L.F_Hz.val) * abs(sys.htts.RAC.Y_L.AC_sensitivity))
#Fb.ax1.semilogx(sys.htts.RAC.Y_L.F_Hz.val, np.ones_like(sys.htts.RAC.Y_L.F_Hz.val) *np.angle(sys.htts.RAC.P_L.AC_sensitivity, deg = True))
#Fb.ax0.loglog(sys.htts.RAC.Y_P.F_Hz.val, np.ones_like(sys.htts.RAC.Y_P.F_Hz.val) * abs(sys.htts.RAC.Y_P.AC_sensitivity))
#Fb.ax1.semilogx(sys.htts.RAC.Y_P.F_Hz.val, np.ones_like(sys.htts.RAC.Y_P.F_Hz.val) *np.angle(sys.htts.RAC.Y_P.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.htts.RAC.Y_Y.F_Hz.val, np.ones_like(sys.htts.RAC.Y_Y.F_Hz.val) * abs(sys.htts.RAC.Y_Y.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.Y_Y.F_Hz.val, np.ones_like(sys.htts.RAC.Y_Y.F_Hz.val) *np.angle(sys.htts.RAC.Y_Y.AC_sensitivity, deg = True))
#Fb.ax0.loglog(sys.htts.RAC.Y_Y.F_Hz.val, np.ones_like(sys.htts.RAC.Y_Y.F_Hz.val) * abs(1 * sys.htts.RAC.P_Y.AC_sensitivity))
#Fb.ax1.semilogx(sys.htts.RAC.Y_Y.F_Hz.val, np.ones_like(sys.htts.RAC.Y_Y.F_Hz.val) *np.angle(1 * sys.htts.RAC.P_Y.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.htts.RAC.Y_Y.F_Hz.val, np.ones_like(sys.htts.RAC.Y_Y.F_Hz.val) * abs(sys.htts.RAC.Y_Y.AC_sensitivity + .2 * sys.htts.RAC.Y_P.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.Y_Y.F_Hz.val, np.ones_like(sys.htts.RAC.Y_Y.F_Hz.val) *np.angle(10 * sys.htts.RAC.Y_P.AC_sensitivity, deg = True))
#Fb.ax0.axvline(1.28)
#Fb.ax0.axvline(1.35)
#Fb.ax0.set_ylim(.1,10)
Fb.ax0.set_xscale('log_zoom')
Fb.ax1.set_xscale('log_zoom')

Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.htts.RAC.UL_UL.F_Hz.val, np.ones_like(sys.htts.RAC.UL_UL.F_Hz.val) * abs(sys.htts.RAC.UL_UL.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.UL_UL.F_Hz.val, np.ones_like(sys.htts.RAC.UL_UL.F_Hz.val) *np.angle(sys.htts.RAC.UL_UL.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.htts.RAC.UL_UR.F_Hz.val, np.ones_like(sys.htts.RAC.UL_UR.F_Hz.val) * abs(sys.htts.RAC.UL_UR.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.UL_UR.F_Hz.val, np.ones_like(sys.htts.RAC.UL_UR.F_Hz.val) *np.angle(sys.htts.RAC.UL_UR.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.htts.RAC.UL_LL.F_Hz.val, np.ones_like(sys.htts.RAC.UL_LL.F_Hz.val) * abs(sys.htts.RAC.UL_LL.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.UL_LL.F_Hz.val, np.ones_like(sys.htts.RAC.UL_LL.F_Hz.val) *np.angle(sys.htts.RAC.UL_LL.AC_sensitivity, deg = True))
Fb.ax0.loglog(sys.htts.RAC.UL_LR.F_Hz.val, np.ones_like(sys.htts.RAC.UL_LR.F_Hz.val) * abs(sys.htts.RAC.UL_LR.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.UL_LR.F_Hz.val, np.ones_like(sys.htts.RAC.UL_LR.F_Hz.val) *np.angle(sys.htts.RAC.UL_LR.AC_sensitivity, deg = True))
Fb.ax0.set_xscale('log_zoom')
Fb.ax1.set_xscale('log_zoom')

# %%
print(np.array([17.38, 105.48, -10.53]) - np.array([-6.72, 80.39, 27.65]))
print(np.array([-30.83, 105.49, -10.53]) - np.array([-6.72, 80.39, 27.65]))
# Out:
# [ 24.1   25.09 -38.18]
# [-24.11  25.1  -38.18]

# %%
from declarative.bunch.hdf_deep_bunch import HDFDeepBunch
data = HDFDeepBunch('/home/mcculler/projects/studies/HTTS/HTTS/FCE/LR_ALL.h5')
dat = data.XFER['M1:ISC-FCI_M1_OSEMINF_LR_IN1']
xfer = dat['M1:ISC-FCI_M1_COILOUTF_LR_EXC']
F = data.FHz.T

data2 = HDFDeepBunch('/home/mcculler/projects/studies/HTTS/HTTS/FCI/LR_ALL.h5')
dat2 = data2.XFER['M1:ISC-FCI_M1_OSEMINF_LR_IN1']
xfer2 = dat2['M1:ISC-FCI_M1_COILOUTF_LR_EXC']

sys = system.system.BGSystem(
    F_AC = F,
)
from phasor.mechanical.models.HTTS import HTTS
sys.own.htts = HTTS()
#
#
Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.htts.RAC.LR_LR.F_Hz.val, np.ones_like(sys.htts.RAC.LR_LR.F_Hz.val) * abs(sys.htts.RAC.LR_LR.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.LR_LR.F_Hz.val, np.ones_like(sys.htts.RAC.LR_LR.F_Hz.val) *np.angle(sys.htts.RAC.LR_LR.AC_sensitivity, deg = True))
Fb.ax0.loglog(F, 5*abs(-xfer))
Fb.ax1.semilogx(F, np.angle(-xfer, deg = True))
Fb.ax0.loglog(F, 5*abs(-xfer2))
Fb.ax1.semilogx(F, np.angle(-xfer2, deg = True))
Fb.ax0.set_xscale('log_zoom')
Fb.ax1.set_xscale('log_zoom')
Fb.ax0.set_xlim(.3, 5)
Fb.ax1.set_xlim(.3, 5)
Fb.ax0.axvline(1.5)
Fb.ax0.axvline(1.6)
Fb.ax0.set_ylim(.1,100)
# Out:
# (0.1, 100)

# %%
from declarative.bunch.hdf_deep_bunch import HDFDeepBunch
data = HDFDeepBunch('/home/mcculler/projects/studies/HTTS/HTTS/FCE/UR_ALL.h5')
dat = data.XFER['M1:ISC-FCI_M1_OSEMINF_UR_IN1']
xfer = dat['M1:ISC-FCI_M1_COILOUTF_UR_EXC']
F = data.FHz.T

data2 = HDFDeepBunch('/home/mcculler/projects/studies/HTTS/HTTS/FCI/UR_ALL.h5')
dat2 = data2.XFER['M1:ISC-FCI_M1_OSEMINF_UR_IN1']
xfer2 = dat2['M1:ISC-FCI_M1_COILOUTF_UR_EXC']

sys = system.system.BGSystem(
    F_AC = F,
)
from phasor.mechanical.models.HTTS import HTTS
sys.own.htts = HTTS()


Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.htts.RAC.UR_UR.F_Hz.val, np.ones_like(sys.htts.RAC.UR_UR.F_Hz.val) * abs(sys.htts.RAC.UR_UR.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.UR_UR.F_Hz.val, np.ones_like(sys.htts.RAC.UR_UR.F_Hz.val) *np.angle(sys.htts.RAC.UR_UR.AC_sensitivity, deg = True))
Fb.ax0.loglog(F, 5*abs(-xfer))
Fb.ax1.semilogx(F, np.angle(-xfer, deg = True))
Fb.ax0.loglog(F, 5*abs(-xfer2))
Fb.ax1.semilogx(F, np.angle(-xfer2, deg = True))
Fb.ax0.set_xscale('log_zoom')
Fb.ax1.set_xscale('log_zoom')
Fb.ax0.set_xlim(.3, 5)
Fb.ax1.set_xlim(.3, 5)
Fb.ax0.axvline(1.5)

Fb.ax0.set_ylim(.1,100)
# Out:
# (0.1, 100)

# %%
from declarative.bunch.hdf_deep_bunch import HDFDeepBunch
data = HDFDeepBunch('/home/mcculler/projects/studies/HTTS/HTTS/FCE/UL_ALL.h5')
dat = data.XFER['M1:ISC-FCI_M1_OSEMINF_UL_IN1']
xfer = dat['M1:ISC-FCI_M1_COILOUTF_UL_EXC']
F = data.FHz.T

data2 = HDFDeepBunch('/home/mcculler/projects/studies/HTTS/HTTS/FCI/UL_ALL.h5')
dat2 = data2.XFER['M1:ISC-FCI_M1_OSEMINF_UL_IN1']
xfer2 = dat2['M1:ISC-FCI_M1_COILOUTF_UL_EXC']
F = data.FHz.T

sys = system.system.BGSystem(
    F_AC = F,
)
from phasor.mechanical.models.HTTS import HTTS
sys.own.htts = HTTS()


Fb = mplfigB(Nrows=2)
Fb.ax0.loglog(sys.htts.RAC.UL_UL.F_Hz.val, np.ones_like(sys.htts.RAC.UL_UL.F_Hz.val) * abs(sys.htts.RAC.UL_UL.AC_sensitivity))
Fb.ax1.semilogx(sys.htts.RAC.UL_UL.F_Hz.val, np.ones_like(sys.htts.RAC.UL_UL.F_Hz.val) *np.angle(sys.htts.RAC.UL_UL.AC_sensitivity, deg = True))
Fb.ax0.loglog(F, 5*abs(-xfer))
Fb.ax1.semilogx(F, np.angle(-xfer, deg = True))
#Fb.ax0.loglog(F, 5*abs(-xfer2))
#Fb.ax1.semilogx(F, np.angle(-xfer2, deg = True))
Fb.ax0.set_xscale('log_zoom')
Fb.ax1.set_xscale('log_zoom')
Fb.ax0.set_xlim(.3, 5)
Fb.ax1.set_xlim(.3, 5)

Fb.ax0.set_ylim(.1,100)
# Out:
# (0.1, 100)

# %%
from declarative.bunch.hdf_deep_bunch import HDFDeepBunch
data2 = HDFDeepBunch('/home/mcculler/projects/studies/HTTS/HTTS/FCE/drive_Y_undamped.h5')
dat2 = data2.XFER['M1:ISC-FCI_M1_DAMP_Y_IN1']
xfer2 = dat2['M1:ISC-FCI_M1_TEST_Y_EXC']
F = data.FHz.T

data = HDFDeepBunch('/home/mcculler/projects/studies/HTTS/HTTS/FCE/drive_L_undamped.h5')
dat = data.XFER['M1:ISC-FCI_M1_DAMP_L_IN1_DQ']
xfer = dat['M1:ISC-FCI_M1_TEST_L_EXC']
F = data.FHz.T

sys = system.system.BGSystem(
    F_AC = F,
)
from phasor.mechanical.models.HTTS import HTTS
sys.own.htts = HTTS()


Fb = mplfigB(Nrows=2)
#Fb.ax0.loglog(sys.htts.RAC.UL_UL.F_Hz.val, np.ones_like(sys.htts.RAC.UL_UL.F_Hz.val) * abs(sys.htts.RAC.UL_UL.AC_sensitivity))
#Fb.ax1.semilogx(sys.htts.RAC.UL_UL.F_Hz.val, np.ones_like(sys.htts.RAC.UL_UL.F_Hz.val) *np.angle(sys.htts.RAC.UL_UL.AC_sensitivity, deg = True))
Fb.ax0.loglog(F, 5*abs(-xfer))
Fb.ax1.semilogx(F, np.angle(-xfer, deg = True))
Fb.ax0.loglog(F, 5*abs(-xfer2))
Fb.ax1.semilogx(F, np.angle(-xfer2, deg = True))
Fb.ax0.set_xscale('log_zoom')
Fb.ax1.set_xscale('log_zoom')
Fb.ax0.set_xlim(.3, 5)
Fb.ax1.set_xlim(.3, 5)
Fb.ax0.axvline(1.2)
Fb.ax0.set_ylim(1e-3, 1e3)
# Out:
# (0.001, 1000.0)

# %%
F.shape

# %%
sys = system.system.BGSystem(
    F_AC = 1,
)
from phasor.mechanical.models.HTTS import HTTS
sys.own.htts = HTTS()

CG = sys.solution.coupling_matrix_get()

# %%
Elambda, EV = np.linalg.eig(CG.array.astype(complex))

# %%
CG.array.astype(complex)

# %%
( 2*3.10/(37000/1e9 / .017**2))**.5 / (2 * np.pi)
# Out:
# 1.1075517706475237

# %%
1.5 * 25.4
# Out:
# 38.099999999999994

# %%
9.81*.0885/2 / .14
# Out:
# 3.100660714285714
