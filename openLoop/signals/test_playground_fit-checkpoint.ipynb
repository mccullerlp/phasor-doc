# %%
import sys
from __future__ import division

# %%
import numpy as np
from openLoop.utilities.ipynb.displays import *
#from YALL.utilities.tabulate import tabulate

import declarative

from declarative.bunch import (
    DeepBunch
)

import openLoop.math.dispatched as dmath 
#import openLoop.math.dispatch_sympy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import openLoop.utilities.version as version
print(version.foundations_version())

from openLoop.utilities.np import logspaced

from openLoop import optics
from openLoop import base 
from openLoop import signals 
from openLoop import system
from openLoop import readouts
# Out:
# b'2017-03-24 15:19:29 -0400 (ffdea8e987e1a50f44075d2d574884f11dc2704e)'

# %%
sys = system.BGSystem(
    F_AC = logspaced(0.001, 100, 1000)
)
sys.own.X1 = signals.SRationalFilter(
    poles_r = (-1, ),
    gain    = 1,
)
sys.own.R1 = readouts.ACReadout(
    portN = sys.X1.Out.o,
    portD = sys.X1.In.i,
)

Fb = mplfigB(Nrows=2)
readoutI =  sys.R1
Fb.ax0.loglog(readoutI.F_Hz.val, abs(readoutI.AC_sensitivity))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(readoutI.AC_sensitivity, deg = True))

# %%
sys = system.BGSystem(
    F_AC = logspaced(0.001, 100, 1000)
)
sys.own.X1 = signals.SRationalFilter(
    zeros_r = (-1, ),
    gain    = 1,
)
sys.own.R1 = readouts.ACReadout(
    portN = sys.X1.Out.o,
    portD = sys.X1.In.i,
)

Fb = mplfigB(Nrows=2)
readoutI =  sys.R1
Fb.ax0.loglog(readoutI.F_Hz.val, abs(readoutI.AC_sensitivity))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(readoutI.AC_sensitivity, deg = True))

# %%
sys = system.BGSystem(
    F_AC = logspaced(0.001, 100, 1000)
)
sys.own.X1 = signals.SRationalFilter(
    zeros_c = (-1 + 10j, ),
    gain    = 1,
)
sys.own.R1 = readouts.ACReadout(
    portN = sys.X1.Out.o,
    portD = sys.X1.In.i,
)

Fb = mplfigB(Nrows=2)
readoutI =  sys.R1
Fb.ax0.loglog(readoutI.F_Hz.val, abs(readoutI.AC_sensitivity))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(readoutI.AC_sensitivity, deg = True))

# %%
sys = system.BGSystem(
    F_AC = logspaced(0.01, 1000, 1000)
)
sys.own.X1 = signals.SRationalFilter(
    poles_c = (-2 - 10j, ),
    zeros_r = (-10, -10),
    gain    = 1,
)
sys.own.R1 = readouts.ACReadout(
    portN = sys.X1.Out.o,
    portD = sys.X1.In.i,
)

Fb = mplfigB(Nrows=2)
readoutI =  sys.R1
Fb.ax0.loglog(readoutI.F_Hz.val, abs(readoutI.AC_sensitivity))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(readoutI.AC_sensitivity, deg = True))

size = len(readoutI.F_Hz.val)
relscale = .1
AC_data = readoutI.AC_sensitivity * (1 
                                     + np.random.normal(0, relscale, size) 
                                     + 1j*np.random.normal(0, relscale, size))
Fb.ax0.loglog(readoutI.F_Hz.val, abs(AC_data))
Fb.ax1.semilogx(readoutI.F_Hz.val, np.angle(AC_data, deg = True))

print(sys.X1.ctree_as_yaml())
# Out:
# delay: {units: second, val: 0}
# gain: 1
# no_DC: false
# poles_c: {'0': !!python/complex '-2.0-10.0j'}
# preserve_plane: true
# zeros_r: {'0': -10, '1': -10}

# %%
import openLoop.fitting.casadi as FIT
froot = FIT.FitterRoot()
froot.own.sym = FIT.FitterSym()
froot.systems.xfer = sys
froot.sym.parameter(sys.X1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-4418681a9297> in <module>()
#       3 froot.my.sym = FIT.FitterSym()
#       4 froot.systems.xfer = sys
# ----> 5 froot.sym.parameter(sys.X1)
#
# /home/mcculler/local/home_sync/projects/openLoop/openLoop/fitting/casadi/symbolics.py in parameter(self, pvalue)
#      39             pvalue,
#      40     ):
# ---> 41         for fdatum in pvalue.fitter_data:
#      42             usecomplex = fdatum.get('usecomplex', False)
#      43             system = pvalue.root
#
# /home/mcculler/local/home_sync/projects/declarative/declarative/properties/memoized.py in __get__(self, obj, cls)
#     108             if result is _UNIQUE_local:
#     109                 try:
# --> 110                     result = self.fget(obj)
#     111                 except TypeError as e:
#     112                     raise_msg_from_property(
#
# /home/mcculler/local/home_sync/projects/openLoop/openLoop/signals/ZPSOS.py in fitter_data(self)
#     234         Combination of all subordinate fitter parameters to fully fit this function
#     235         """
# --> 236         fitters = self.fitter_data_()
#     237         #fitters.extend(self.delay.fitter_data)
#     238         #fitters.extend(self.gain.fitter_data)
#
# /home/mcculler/local/home_sync/projects/openLoop/openLoop/signals/ZPSOS.py in fitter_data_(self)
#     141         for pname, pval in self.ctree['zeros_r'].items():
#     142             fitters.append(
# --> 143                 add_fit('zeros_r', pval)
#     144             )
#     145         for pname, pval in self.ctree['poles_r'].items():
#
# /home/mcculler/local/home_sync/projects/openLoop/openLoop/signals/ZPSOS.py in add_fit(root_key, sub_key, usecomplex)
#     117             if self.preserve_plane:
#     118                 #get the initial value and create the constraint for it
# --> 119                 if fitter_initial(self.root.ctree) <= 0:
#     120                     lower_bound = -float('inf')
#     121                     upper_bound = 0
#
# /home/mcculler/local/home_sync/projects/openLoop/openLoop/signals/ZPSOS.py in fitter_initial(ooa)
#     112                 for key in fitter_parameter:
#     113                     ooa = ooa[key]
# --> 114                 val = ooa.get[sub_key]
#     115                 return val
#     116
#
# TypeError: 'method' object is not subscriptable
